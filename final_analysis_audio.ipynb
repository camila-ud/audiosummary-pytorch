# %% [markdown]
# Notebook cluster all wav files

# %%
#--mesure time
import time 

# graphs
from tqdm import tqdm
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('bmh')

#summary

from summary import *

# %%
#filepath dataclean
filepath = '/home/brain/Desktop/BrainSongs/git/caroltrio_perf/data_clean/'
listfiles = os.listdir(filepath)
listwav = []
for c in listfiles:
    if c[-3:] == 'wav':
        listwav.append(os.path.join(filepath,c))

# %%
listwav
# Out:
# ['/home/brain/Desktop/BrainSongs/git/caroltrio_perf/data_clean/caroleeg_sess2.wav',
#  '/home/brain/Desktop/BrainSongs/git/caroltrio_perf/data_clean/caroleeg_sess4_1.wav',
#  '/home/brain/Desktop/BrainSongs/git/caroltrio_perf/data_clean/caroleeg_sess6.wav',
#  '/home/brain/Desktop/BrainSongs/git/caroltrio_perf/data_clean/caroleeg_perf1.wav',
#  '/home/brain/Desktop/BrainSongs/git/caroltrio_perf/data_clean/caroleeg_sess5_2.wav',
#  '/home/brain/Desktop/BrainSongs/git/caroltrio_perf/data_clean/caroleeg_sess5_1.wav',
#  '/home/brain/Desktop/BrainSongs/git/caroltrio_perf/data_clean/caroleeg_sess4_2.wav',
#  '/home/brain/Desktop/BrainSongs/git/caroltrio_perf/data_clean/caroleeg_sess3.wav',
#  '/home/brain/Desktop/BrainSongs/git/caroltrio_perf/data_clean/caroleeg_sess4_3.wav',
#  '/home/brain/Desktop/BrainSongs/git/caroltrio_perf/data_clean/caroleeg_perf2.wav']

# %% [markdown]
# - The first version reduces the number of clusters using as criteria the relationship between the mean and the standard deviation.
# - The second version only takes the number of clusters that have more than 0.1 samples.
# *This is the best*

# %%
def analyse(id,version = False):
    curwav = listwav[id]
    name = curwav.split('/')[8][:-4] 
    print("Analysing {}".format(name))
    #input,output
    if version:
        automatic_summary_v2(curwav,"resultsv2/{}".format(name),True)
    else:
        automatic_summary(curwav,"results/{}".format(name),True)

# %% [markdown]
# ### **note** :
# Insufficient RAM, it is necessary to analyze the audios individually

# %% [markdown]
# ------
# ## version 2

# %%
version = True

# %%
analyse(0,version)
# Out:
# Analysing caroleeg_sess2
# time:  0.09382987022399902
# Tensor shape: torch.Size([1, 1, 19999350, 1])
#   0%|          | 0/29 [00:00<?, ?it/s]
# Features:
#
# [(1, 16, 1249959, 1), (1, 32, 78122, 1), (1, 64, 39062, 1), (1, 128, 19532, 1), (1, 256, 2441, 1), (1, 512, 1221, 1), (1, 1024, 611, 1), (1, 1000, 302, 1), (1, 401, 302, 1)]
# Cout :  1024
# /home/brain/miniconda3/lib/python3.7/site-packages/sklearn/manifold/spectral_embedding_.py:235: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
#   3%|▎         | 1/29 [00:00<00:10,  2.67it/s]/home/brain/miniconda3/lib/python3.7/site-packages/sklearn/manifold/spectral_embedding_.py:235: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# ...
#   0%|          | 0/9 [00:00<?, ?it/s]
# Best number of neighbors is 4
# ...

# %%
analyse(1,version)
# Out:
# Analysing caroleeg_sess4_1
# time:  0.05150771141052246
# Tensor shape: torch.Size([1, 1, 11973150, 1])
#   0%|          | 0/29 [00:00<?, ?it/s]/home/brain/miniconda3/lib/python3.7/site-packages/sklearn/manifold/spectral_embedding_.py:235: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
#   3%|▎         | 1/29 [00:00<00:03,  7.31it/s]
# Features:
#
# [(1, 16, 748322, 1), (1, 32, 46770, 1), (1, 64, 23386, 1), (1, 128, 11694, 1), (1, 256, 1462, 1), (1, 512, 732, 1), (1, 1024, 367, 1), (1, 1000, 180, 1), (1, 401, 180, 1)]
# Cout :  1024
# /home/brain/miniconda3/lib/python3.7/site-packages/sklearn/manifold/spectral_embedding_.py:235: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# ...
#  11%|█         | 1/9 [00:00<00:01,  7.25it/s]
# Best number of neighbors is 4
# ...

# %%
analyse(2,version)
# Out:
# Analysing caroleeg_sess6
# time:  0.15384840965270996
# Tensor shape: torch.Size([1, 1, 38014200, 1])
#   0%|          | 0/29 [00:00<?, ?it/s]
# Features:
#
# [(1, 16, 2375887, 1), (1, 32, 148493, 1), (1, 64, 74247, 1), (1, 128, 37124, 1), (1, 256, 4640, 1), (1, 512, 2321, 1), (1, 1024, 1161, 1), (1, 1000, 577, 1), (1, 401, 577, 1)]
# Cout :  1024
# /home/brain/miniconda3/lib/python3.7/site-packages/sklearn/manifold/spectral_embedding_.py:235: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
#   3%|▎         | 1/29 [00:00<00:24,  1.15it/s]/home/brain/miniconda3/lib/python3.7/site-packages/sklearn/manifold/spectral_embedding_.py:235: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# ...
#   0%|          | 0/9 [00:00<?, ?it/s]
# Best number of neighbors is 4
# ...

# %%
analyse(3,version)
# Out:
# Analysing caroleeg_perf1
# time:  0.08506083488464355
# Tensor shape: torch.Size([1, 1, 17397450, 1])
#   0%|          | 0/29 [00:00<?, ?it/s]/home/brain/miniconda3/lib/python3.7/site-packages/sklearn/manifold/spectral_embedding_.py:235: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
#   3%|▎         | 1/29 [00:00<00:03,  7.37it/s]
# Features:
#
# [(1, 16, 1087340, 1), (1, 32, 67958, 1), (1, 64, 33980, 1), (1, 128, 16991, 1), (1, 256, 2124, 1), (1, 512, 1063, 1), (1, 1024, 532, 1), (1, 1000, 263, 1), (1, 401, 263, 1)]
# Cout :  1024
# /home/brain/miniconda3/lib/python3.7/site-packages/sklearn/manifold/spectral_embedding_.py:235: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# ...

# %%
analyse(4,version)
# Out:
# Analysing caroleeg_sess5_2
# time:  0.08033609390258789
# Tensor shape: torch.Size([1, 1, 19734750, 1])
#   0%|          | 0/29 [00:00<?, ?it/s]
# Features:
#
# [(1, 16, 1233422, 1), (1, 32, 77089, 1), (1, 64, 38545, 1), (1, 128, 19273, 1), (1, 256, 2409, 1), (1, 512, 1205, 1), (1, 1024, 603, 1), (1, 1000, 298, 1), (1, 401, 298, 1)]
# Cout :  1024
# /home/brain/miniconda3/lib/python3.7/site-packages/sklearn/manifold/spectral_embedding_.py:235: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
#   3%|▎         | 1/29 [00:00<00:07,  3.88it/s]/home/brain/miniconda3/lib/python3.7/site-packages/sklearn/manifold/spectral_embedding_.py:235: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# ...

# %%
analyse(5,version)
# Out:
# Analysing caroleeg_sess5_1
# time:  0.05695366859436035
# Tensor shape: torch.Size([1, 1, 13274100, 1])
#   0%|          | 0/29 [00:00<?, ?it/s]/home/brain/miniconda3/lib/python3.7/site-packages/sklearn/manifold/spectral_embedding_.py:235: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
#   3%|▎         | 1/29 [00:00<00:03,  7.51it/s]
# Features:
#
# [(1, 16, 829631, 1), (1, 32, 51852, 1), (1, 64, 25927, 1), (1, 128, 12964, 1), (1, 256, 1620, 1), (1, 512, 811, 1), (1, 1024, 406, 1), (1, 1000, 200, 1), (1, 401, 200, 1)]
# Cout :  1024
# /home/brain/miniconda3/lib/python3.7/site-packages/sklearn/manifold/spectral_embedding_.py:235: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# ...
#  11%|█         | 1/9 [00:00<00:01,  7.80it/s]
# Best number of neighbors is 14
# ...

# %%
analyse(6,version)
# Out:
# Analysing caroleeg_sess4_2
# time:  0.05441093444824219
# Tensor shape: torch.Size([1, 1, 12315928, 1])
#   0%|          | 0/29 [00:00<?, ?it/s]/home/brain/miniconda3/lib/python3.7/site-packages/sklearn/manifold/spectral_embedding_.py:235: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
#   3%|▎         | 1/29 [00:00<00:03,  7.45it/s]
# Features:
#
# [(1, 16, 769745, 1), (1, 32, 48109, 1), (1, 64, 24055, 1), (1, 128, 12028, 1), (1, 256, 1503, 1), (1, 512, 752, 1), (1, 1024, 377, 1), (1, 1000, 185, 1), (1, 401, 185, 1)]
# Cout :  1024
# /home/brain/miniconda3/lib/python3.7/site-packages/sklearn/manifold/spectral_embedding_.py:235: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# ...
#  11%|█         | 1/9 [00:00<00:01,  7.30it/s]
# Best number of neighbors is 6
# ...

# %%
analyse(7,version)
# Out:
# Analysing caroleeg_sess3
# time:  0.1466665267944336
# Tensor shape: torch.Size([1, 1, 37507050, 1])
#   0%|          | 0/29 [00:00<?, ?it/s]
# Features:
#
# [(1, 16, 2344190, 1), (1, 32, 146512, 1), (1, 64, 73257, 1), (1, 128, 36629, 1), (1, 256, 4578, 1), (1, 512, 2290, 1), (1, 1024, 1146, 1), (1, 1000, 570, 1), (1, 401, 570, 1)]
# Cout :  1024
# /home/brain/miniconda3/lib/python3.7/site-packages/sklearn/manifold/spectral_embedding_.py:235: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
#   3%|▎         | 1/29 [00:00<00:19,  1.46it/s]/home/brain/miniconda3/lib/python3.7/site-packages/sklearn/manifold/spectral_embedding_.py:235: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# ...
#   0%|          | 0/9 [00:00<?, ?it/s]
# Best number of neighbors is 4
# ...

# %%
analyse(8,version)
# Out:
# Analysing caroleeg_sess4_3
# time:  0.046826839447021484
# Tensor shape: torch.Size([1, 1, 9988650, 1])
#   0%|          | 0/29 [00:00<?, ?it/s]
# Features:
#
# [(1, 16, 624290, 1), (1, 32, 39018, 1), (1, 64, 19510, 1), (1, 128, 9756, 1), (1, 256, 1219, 1), (1, 512, 610, 1), (1, 1024, 306, 1), (1, 1000, 150, 1), (1, 401, 150, 1)]
# Cout :  1024
# /home/brain/miniconda3/lib/python3.7/site-packages/sklearn/manifold/spectral_embedding_.py:235: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
#   3%|▎         | 1/29 [00:00<00:06,  4.37it/s]/home/brain/miniconda3/lib/python3.7/site-packages/sklearn/manifold/spectral_embedding_.py:235: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# ...

# %%
analyse(9,version)
# Out:
# Analysing caroleeg_perf2
# time:  0.09423494338989258
# Tensor shape: torch.Size([1, 1, 23108400, 1])
#   0%|          | 0/29 [00:00<?, ?it/s]
# Features:
#
# [(1, 16, 1444275, 1), (1, 32, 90267, 1), (1, 64, 45134, 1), (1, 128, 22568, 1), (1, 256, 2821, 1), (1, 512, 1411, 1), (1, 1024, 706, 1), (1, 1000, 350, 1), (1, 401, 350, 1)]
# Cout :  1024
# /home/brain/miniconda3/lib/python3.7/site-packages/sklearn/manifold/spectral_embedding_.py:235: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
#   3%|▎         | 1/29 [00:00<00:07,  3.67it/s]/home/brain/miniconda3/lib/python3.7/site-packages/sklearn/manifold/spectral_embedding_.py:235: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# ...
#   0%|          | 0/9 [00:00<?, ?it/s]
# Best number of neighbors is 4
# ...
